# %%
import pandas as pd 
import seaborn as sns
import numpy as np 
df = pd.read_csv('D:/Datasets/World Happenis Report Dataset/2016.csv')
df.head(4)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# ...

# %% [markdown]
# ### EDA :

# %%
# Lables of the dataset
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
# The shape of the dataset
df.shape
# Out:
# (157, 13)

# %%
# Checking if there are missing values in the dataset
df.isna().sum().sum()
# Out:
# 0

# %%
# Data types of the features
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# Correlation matrix 
sns.heatmap(df.corr(), vmin = -1, vmax = 1, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### We observe that 'Economy', 'Health', and 'Family' have the highest correlation value, I excluded the upper and lower confidence intervals, since they are used to conduct the regression and we will not be able to extract features related to the Happiness Score

# %% [markdown]
# ### Data Cleaning, and Feature Selection

# %%
df = df.drop(['Lower Confidence Interval', 'Upper Confidence Interval', 'Generosity'], axis = 1 )
df.shape
# Out:
# (157, 10)

# %% [markdown]
# ### let's export the dataset in Tableau to perform the Visualization

# %%
df.to_csv('WHR_2016_Cleaned.csv', index = False )
